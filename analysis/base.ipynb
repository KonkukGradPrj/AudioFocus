# %%
loss = 0
for epoch in range(40):   
    
    for idx in range(4):  
        print(f"epoch{epoch}, idx{idx}")
        print(40 * (idx + 1) // 4 > epoch)      

        if  40 * (idx + 1) // 4  > epoch or loss > 100:
            break
# Out:
# epoch0, idx0
# True
# epoch1, idx0
# True
# epoch2, idx0
# True
# epoch3, idx0
# True
# epoch4, idx0
# True
# epoch5, idx0
# True
# epoch6, idx0
# True
# epoch7, idx0
# True
# epoch8, idx0
# True
# epoch9, idx0
# True
# epoch10, idx0
# False
# epoch10, idx1
# True
# epoch11, idx0
# False
# epoch11, idx1
# True
# epoch12, idx0
# False
# epoch12, idx1
# True
# epoch13, idx0
# False
# epoch13, idx1
# True
# epoch14, idx0
# False
# epoch14, idx1
# True
# epoch15, idx0
# False
# epoch15, idx1
# True
# epoch16, idx0
# False
# epoch16, idx1
# True
# epoch17, idx0
# False
# epoch17, idx1
# True
# epoch18, idx0
# False
# epoch18, idx1
# True
# epoch19, idx0
# False
# epoch19, idx1
# True
# epoch20, idx0
# False
# epoch20, idx1
# False
# epoch20, idx2
# True
# epoch21, idx0
# False
# epoch21, idx1
# False
# epoch21, idx2
# True
# epoch22, idx0
# False
# epoch22, idx1
# False
# epoch22, idx2
# True
# epoch23, idx0
# False
# epoch23, idx1
# False
# epoch23, idx2
# True
# epoch24, idx0
# False
# epoch24, idx1
# False
# epoch24, idx2
# True
# epoch25, idx0
# False
# epoch25, idx1
# False
# epoch25, idx2
# True
# epoch26, idx0
# False
# epoch26, idx1
# False
# epoch26, idx2
# True
# epoch27, idx0
# False
# epoch27, idx1
# False
# epoch27, idx2
# True
# epoch28, idx0
# False
# epoch28, idx1
# False
# epoch28, idx2
# True
# epoch29, idx0
# False
# epoch29, idx1
# False
# epoch29, idx2
# True
# epoch30, idx0
# False
# epoch30, idx1
# False
# epoch30, idx2
# False
# epoch30, idx3
# True
# epoch31, idx0
# False
# epoch31, idx1
# False
# epoch31, idx2
# False
# epoch31, idx3
# True
# epoch32, idx0
# False
# epoch32, idx1
# False
# epoch32, idx2
# False
# epoch32, idx3
# True
# epoch33, idx0
# False
# epoch33, idx1
# False
# epoch33, idx2
# False
# epoch33, idx3
# True
# epoch34, idx0
# False
# epoch34, idx1
# False
# epoch34, idx2
# False
# epoch34, idx3
# True
# epoch35, idx0
# False
# epoch35, idx1
# False
# epoch35, idx2
# False
# epoch35, idx3
# True
# epoch36, idx0
# False
# epoch36, idx1
# False
# epoch36, idx2
# False
# epoch36, idx3
# True
# epoch37, idx0
# False
# epoch37, idx1
# False
# epoch37, idx2
# False
# epoch37, idx3
# True
# epoch38, idx0
# False
# epoch38, idx1
# False
# epoch38, idx2
# False
# epoch38, idx3
# True
# epoch39, idx0
# False
# epoch39, idx1
# False
# epoch39, idx2
# False
# epoch39, idx3
# True

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
from wandb_utils import *

# %% [markdown]
# #### Get Runs from Wandb

# %%
runs_df = collect_runs('hyeonsio/AudioFocus')

# %% [markdown]
# #### Get data from wandb log

# %%
runs_df = filter_runs(runs_df, , group_name='') # , group_name=''
runs_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 runs_df = filter_runs(runs_df) # , group_name=''
#       2 runs_df
#
# TypeError: filter_runs() missing 2 required positional arguments: 'group_name' and 'exp_names'
